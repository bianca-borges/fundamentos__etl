# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.loc[1, 'ocorrencia_cidade'] # pesquisar por cidade
# Out:
# 'BELÉM'

# %%
df.loc[1:3] # pesquisar por labels
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df.loc[[10,40]] # pesquisar mais de 1 label
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
df.loc[:, 'ocorrencia_cidade'] # pesquisar todas as cidades
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
df.codigo_ocorrencia.is_unique # verificar se os dados são unicos
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True) # mudar o label para outro identificador

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df.loc[40324] # pesquisar por label codigo_ocorrencia
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %%
df.reset_index(drop=True, inplace=True) # desfazer label codigo_ocorrencia

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
df.loc[0, 'ocorrencia_aerodromo'] = '' # mudar o valor do campo ocorrencia_aerodromo para vazio

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
#
#    total_recomendacoes
# 0                    0

# %%
df.loc[1] = 20 # mudar todos os campos do label 1 para 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
# 1                  20                       20                20
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
#
#    total_recomendacoes
# 0                    0
# 1                   20

# %%
df.loc[:, 'total_recomendacoes'] = 10 # mudar todos os valores da coluna total_recomendacoes para 10

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 ****  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes
# 0                   10
# 1                   10
# 2                   10
# ...

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf # fazer bkup de uma coluna

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 6109               80245                INCIDENTE              RECIFE
# 6110               80247                INCIDENTE         PORTO VELHO
# 6111               80251                INCIDENTE               BELÉM
# 6112               80257                 ACIDENTE          DOM AQUINO
# 6113               80259                INCIDENTE            CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE' # alterar ocorrencia_classificacao para GRAVE, onde a coluna ocorrencia_uf tenha o valor SP

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 6109               80245                INCIDENTE              RECIFE
# 6110               80247                INCIDENTE         PORTO VELHO
# 6111               80251                INCIDENTE               BELÉM
# 6112               80257                 ACIDENTE          DOM AQUINO
# 6113               80259                    GRAVE            CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP'] # filtrar para todas as cidades com ocorrencia_uf == SP
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 11                 40069                    GRAVE          SÃO PAULO
# 16                 39809                    GRAVE          SÃO PAULO
# 18                 39828                    GRAVE             SANTOS
# 26                 39847                    GRAVE           SOROCABA
# 27                 39768                    GRAVE           CAMPINAS
# ...                  ...                      ...                ...
# 6084               80234                    GRAVE          SÃO PAULO
# 6085               80208                    GRAVE          SÃO PAULO
# 6104               80238                    GRAVE        VOTUPORANGA
# 6108               80244                    GRAVE  BRAGANÇA PAULISTA
# 6113               80259                    GRAVE           CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# Limpando os dados

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.replace(['**', '###!', '####', '****', '*****', 'NULL'], pd.NA, inplace=True)

# %%
df.isna().sum() # contabilizar dados substituidos
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.fillna(0, inplace=True) # muda todos os valores nulos para 0

# %%
df.isnull().sum() # contabilizar dados substituidos
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                    0     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %%
df.isnull().sum() # contabilizar dados substituidos
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.replace([0], pd.NA, inplace=True) # susbstitui o valor 0 por NA

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes         5341
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':0}, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [raw]
# Excluir colunas

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                    0     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                    0     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0        12:00:00                    0                        0
# ...

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                    0     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                    0     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %% [raw]
# df.dropna() # exclui todas as linhas com valores NA

# %%
df.dropna(subset=['ocorrencia_uf']) # exclui o valor NA do campo ocorrencia_uf
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# df.drop_duplicates() # exclui linha duplicada
